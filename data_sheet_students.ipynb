# %% [markdown]
# #tuto2
#
# today we analyse an excel file

# %%
import pandas as pd

# %% [markdown]
# Call the excel file that contains our 'countries' data and put it in a dataframe (df)

# %%
df = pd.read_excel('C:\\Users\maxim\Desktop\Data-sheet-STUDENTS.xlsx',
             header=2,
             usecols=[1],
             names=['countries'])

# %%
df
# Out:
#                              countries
# 0                          Afghanistan
# 1                              Albania
# 2                              Armenia
# 3                           Azerbaijan
# 4                              Bahrain
# 5                           Bangladesh
# 6                              Belarus
# 7                               Bhutan
# 8               Bosnia and Herzegovina
# 9                               Brunei
# 10                            Bulgaria
# 11                            Cambodia
# 12                               China
# 13                             Croatia
# 14                      Czech Republic
# 15                          East Timor
# 16                               Egypt
# 17                             Estonia
# 18                    France (Not BRI)
# 19                             Georgia
# 20                   Germany (not BRI)
# 21                             Hungary
# 22                               India
# ...

# %%
countries={}   #create a dictionnary
for country in df['countries']:
    countries[country]={}
countries
# Out:
# {'Afghanistan': {},
#  'Albania': {},
#  'Armenia': {},
#  'Azerbaijan': {},
#  'Bahrain': {},
#  'Bangladesh': {},
#  'Belarus': {},
#  'Bhutan': {},
#  'Bosnia and Herzegovina': {},
#  'Brunei': {},
#  'Bulgaria': {},
#  'Cambodia': {},
#  'China': {},
#  'Croatia': {},
#  'Czech Republic': {},
#  'East Timor': {},
#  'Egypt': {},
#  'Estonia': {},
#  'France (Not BRI)': {},
#  'Georgia': {},
#  'Germany (not BRI)': {},
#  'Hungary': {},
#  'India': {},
#  'Indonesia': {},
#  'Iran': {},
#  'Iraq': {},
#  'Israel': {},
#  'Jordan': {},
#  'Kazakhstan': {},
#  'Kuwait': {},
#  'Kyrgyzstan': {},
#  'Laos': {},
#  'Latvia': {},
#  'Lebanon': {},
#  'Lithuania': {},
#  'Macedonia': {},
#  'Malaysia': {},
#  'Maldives': {},
#  'Moldova': {},
#  'Mongolia': {},
#  'Montenegro': {},
#  'Myanmar': {},
#  'Nepal': {},
#  'Oman': {},
#  'Pakistan': {},
#  'Philippines': {},
#  'Poland': {},
#  'Qatar': {},
#  'Romania': {},
#  'Russia': {},
#  'Saudi Arabia': {},
#  'Serbia': {},
# ...

# %% [markdown]
# #we see that there is some pb with some countries, example of the (Not BRI)
# #So we go on the Internet get some values from API
# #then we catch that there is a ISO code for each country (ex:FRANCE, fr...)

# %%
#import requests
#from tqdm import tnrange, tqdm_notebook
#from time import sleep

#for i in tnrange (len(countries.keys())):
#for country in countries:
#    try:
        #country=list(countries.keys())[i]
#        url='https://restcountries.eu/rest/v2/name/'+country
#        r=requests.get(url)
#        data= r.json()
#        countries[country]['alpha2Code']=data[0]['alpha2Code']
#    except KeyError:
#        print (data)
#        sleep(1)    
        
        
import requests
from time import sleep
url = 'https://restcountries.eu/rest/v2/name/'
for country in countries:
    try:
        r = requests.get(url + country)
        data = r.json()
        countries[country]['alpha2Code'] = data[0]['alpha2Code']
    except KeyError:
        print(data)
        sleep(3)
# Out:
# {'status': 404, 'message': 'Not Found'}
# {'status': 404, 'message': 'Not Found'}
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     443             try:
# --> 444                 cnx.do_handshake()
#     445             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1906         result = _lib.SSL_do_handshake(self._ssl)
# -> 1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1631                         raise SysCallError(errno, errorcode.get(errno))
# -> 1632                 raise SysCallError(-1, "Unexpected EOF")
#    1633             else:
#
# ...

# %% [markdown]
# #I got a pb with the code but I know that there are 6countries that don't fit well

# %%
for k,v in countries.items():
    if len(v.keys()) == 0:
        if 'not bri' in k.lower():
            country=(k.split('(')[0].strip())
        elif k=='Thailiand':
            country='thailiand'
        else:
            country=k[4:]
        try:
            url='https://restcountries.eu/rest/v2/name/' + country
            r=requests.get(url)
            data= r.json()
            countries[k]['alpha2Code']=data[0]['alpha2Code']
        except KeyError:
            print(data)
            sleep(2)
countries
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %% [markdown]
# Use the API from the world bank

# %%
for k,v in countries.items():
    try:
        url='http://api.worldbank.org/v2/countries/'+v['alpha2Code']+'/indicators/NY.GDP.MKTP.CD?format=json'   
        r=requests.get(url)
        data= r.json()
        print(k)
        countries[k]['gdp']=float(data[1][0]['value'])
        sleep(1)
    except IndexError:
        print(k,'has an index problem',data)
    except TypeError:
        print(k,'has a type error',data)
# Out:
# Afghanistan
# Albania
# Armenia
# Azerbaijan
# Bahrain
# Bangladesh
# Belarus
# Bhutan
# Bosnia and Herzegovina
# Brunei
# Bulgaria
# Cambodia
# China
# Croatia
# Czech Republic
# East Timor
# Egypt
# Estonia
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-376dee7fd6e2> in <module>()
#       1 for k,v in countries.items():
#       2     try:
# ----> 3         url='http://api.worldbank.org/v2/countries/'+v['alpha2Code']+'/indicators/NY.GDP.MKTP.CD?format=json'
#       4         r=requests.get(url)
#       5         data= r.json()
#
# KeyError: 'alpha2Code'

# %% [markdown]
# There are still pb with some countries India Yemen Syria

# %%
countries['India']['alpha2Code']='IN' 
url = 'http://api.worldbank.org/v2/countries/IN/indicators/NY.GDP.MKTP.CD?format=json'
r=requests.get(url)
data=r.json()
countries['India']['gdp']= float(data[1][0]['value'])
countries

#there is no gpd for those countries as they are at war Yemen and Syria
countries['Yemen']['gdp']= NONE 
countries['Syria']['gdp']= NONE
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ...

# %%
s=pd.Series([v['gdp']for k,v in countries.items()])
df['gdp']=s
df.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-cd065397709e> in <module>()
# ----> 1 s=pd.Series([v['gdp']for k,v in countries.items()])
#
# <ipython-input-27-cd065397709e> in <listcomp>(.0)
# ----> 1 s=pd.Series([v['gdp']for k,v in countries.items()])
#
# KeyError: 'gdp'

# %% [markdown]
# #draw a graph with matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.plot()
pd.write_excel()

# %% [markdown]
# #rewrite an excel file as we actually have an excel at the beginning

# %%
writer=pd.ExcelWriter('output.xlsx')
df.to_excel(excel)
writer.save()
