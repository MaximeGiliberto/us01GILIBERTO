# %%
import pandas as pd

# %%
df= pd.read_csv ('C:\\Users\\maxim\\Documents\\Urban Data Hackathon\\UTSEUS-MOBIKE-shanghai_full.csv', delimiter=',', encoding='utf-8')

# %%
df['start_time']=pd.to_datetime(df['start_time'])
df['end_time']=pd.to_datetime(df['end_time'])
df[df.start_location_x == 121.416]

df
# Out:
#          orderid  bikeid  userid          start_time  start_location_x  \
# 0              1  324731    7541 2016-08-28 00:00:00           121.490
# 1              6  288841    4427 2016-08-28 00:00:00           121.462
# 2              8  315873    6474 2016-08-28 00:00:00           121.416
# 3             10   93155   12616 2016-08-28 00:00:00           121.436
# 4             11  352484   11596 2016-08-28 00:00:00           121.459
# 5             13  127840    9570 2016-08-28 00:00:00           121.353
# 6             15  125990   15692 2016-08-28 00:00:00           121.441
# 7             16  346549    4373 2016-08-28 00:00:00           121.426
# 8             17  352552     350 2016-08-28 00:00:00           121.524
# 9             20  351480   16317 2016-08-28 00:00:00           121.442
# 10            21  130705   13646 2016-08-28 00:00:00           121.381
# 11            22  348492     840 2016-08-28 00:00:00           121.407
# ...

# %%
df_filtered= df[df.start_location_x <= 121.416 ]
df_filtered_2= df_filtered[df_filtered.start_location_x >= 121]
df_filtered_3=df_filtered_2.round(2)
df_filtered_3
# Out:
#          orderid  bikeid  userid          start_time  start_location_x  \
# 2              8  315873    6474 2016-08-28 00:00:00            121.42
# 5             13  127840    9570 2016-08-28 00:00:00            121.35
# 10            21  130705   13646 2016-08-28 00:00:00            121.38
# 11            22  348492     840 2016-08-28 00:00:00            121.41
# 16            31  266405    2975 2016-08-28 00:01:00            121.30
# 17            33   70710     143 2016-08-28 00:00:00            121.41
# 20            36  330092    8215 2016-08-28 00:01:00            121.38
# 24            42  256000    5740 2016-08-28 00:01:00            121.41
# 32            56  310717   16329 2016-08-28 00:01:00            121.34
# 37            72  328394   16324 2016-08-28 00:03:00            121.40
# 38            73  281025    4138 2016-08-28 00:04:00            121.32
# 64           129  260659    9104 2016-08-28 00:16:00            121.37
# ...

# %%
df_filtered= df_filtered.round(2)
df_filtered_2=df_filtered[df_filtered.start_location_x == 121.41]
#df_filtered_2= df_filtered[df_filtered.start_location_x >= 121]

df_filtered_2['userid']value_counts()
# Out:
#   File "<ipython-input-39-cabfdec28c0f>", line 5
#     df_filtered_2['userid']value_counts()
#                                       ^
# SyntaxError: invalid syntax
